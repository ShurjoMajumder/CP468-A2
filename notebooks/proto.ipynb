# %%
import numpy as np
import pandas as pd
from scipy.sparse import csr_matrix
from matplotlib import pyplot as plt

# %%
frame = pd.read_csv("../results/grid_search_alpha_gamma_q_iterations.csv")

# %%
clean_frame = frame.drop(["epsilon", "epsilon_decay", "epsilon_min", 'sweep_type'], axis=1, inplace=True)

# %%
finished = frame[frame["finished"] == True]

# %%
finished.drop(["finished"], axis=1, inplace=True)

# %%
finished.sort_values(by=["steps_taken", "alpha", "q_iterations", "gamma"], inplace=True)

# %%
finished
# Out:
#       seed  alpha  gamma  q_iterations  steps_taken  run_idx
# 249  25051    0.8   0.95             1            2        9
# 229  23051    0.8   0.90             5            2        9
# 34    4046    0.4   0.90             1            3        4
# 114  12046    0.6   0.80            10            3        4
# 48    5050    0.4   0.90             5            4        8
# ..     ...    ...    ...           ...          ...      ...
# 156  16048    0.6   0.95             1          134        6
# 61    7043    0.4   0.95             1          140        1
# 164  17046    0.6   0.95             5          141        4
# 35    4047    0.4   0.90             1          159        5
# 221  23043    0.8   0.90             5          174        1
#
# [268 rows x 6 columns]

# %%
finished[finished["steps_taken"] < 10].plot.scatter(x="q_iterations", y="steps_taken")
plt.show()
